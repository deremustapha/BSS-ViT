# %%
from db1_preprocess_utils import *
from feature_extraction import *
from experiment_one_utils import *
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# 2023-09-04 13:41:53.401197: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-04 13:41:56.603196: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-09-04 13:42:05.870479: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/nvidia/cudnn/lib:/home/bmis/anaconda3/envs/tf/lib/:
# 2023-09-04 13:42:05.870753: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/nvidia/cudnn/lib:/home/bmis/anaconda3/envs/tf/lib/:
# 2023-09-04 13:42:05.870773: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.model_selection import KFold
from scipy.signal import stft

# %%
path = '/home/bmis/Documents/AI-Workspace/sEMG/GestureClassificationUsingCViT/data/DB1/raw'

signal_type='raw'
input_type='raw'
n_channels=64
low_cut=20
high_cut=500
order=6 
window_size=50
overlap=50
fs=2048

whiten=False
center=False
extend=True
extend_size=4
normalize=False
mu=0

start_subject = 1
total_subject = 20
session=[1,2]
ratio = 0.2

noise_db = [5,10,15]
std = 1
stochastic_depth_rate = 0.1

# %%
data, label, X_test, y_test = get_experiment_data(path, subjects=start_subject, sessions=session,
                                                       signal_type='raw', input_type=input_type, 
                                                       channels=n_channels, low_cut=20, high_cut=500,
                                                      order=6, window_size=window_size, overlap=overlap, fs=fs, 
                                                      extend=extend, center=center, 
                                                      extend_size=extend_size, whiten=whiten,
                                                      normalize=False, mu=0, ratio=0.2)
# Out:
# ####################################################################################
# Loading subject 1
# ####################################################################################
# Extended.
# Size of the input data is (17152, 320, 102, 1)
# The input label shape is (17152,)
# The total number of classes is 34
# ************************************************************************************
# Loaded RAW input data
# ************************************************************************************

# %%
data.shape, label.shape, X_test.shape, y_test.shape
# Out:
# ((17152, 320, 102, 1), (17152,), (4288, 320, 102), (4288,))

# %%
#Hyper-parameter

input_shape = data.shape[1:]
patch_size = 8
n_patches = 120
dims = n_patches + 1 
n_transformer_layers = 2
n_heads = 2
transformer_units = [dims * 2,dims]  # Size of the transformer layers
mlp_head_units = [128, 34]   # [2048, 1024]
n_classes = len(np.unique(label))
stochastic_depth = False

stochastic_depth_rate = 0.1

n_batches = 32
n_epochs = 150
n_folds = 3
type_of_experiment = 2

# %%
model = vit_gesture_classification(input_shape, dims, patch_size, n_patches,
                                  n_transformer_layers, n_heads, transformer_units,
                                   mlp_head_units, n_classes,stochastic_depth,stochastic_depth_rate)

model.summary()
# Out:
# 2023-09-04 13:43:14.174445: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-09-04 13:43:15.641207: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-09-04 13:43:15.641465: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-09-04 13:43:15.667886: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-04 13:43:15.678397: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-09-04 13:43:15.678785: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-09-04 13:43:15.679023: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-09-04 13:43:20.131251: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-09-04 13:43:20.131629: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-09-04 13:43:20.131852: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-09-04 13:43:20.144183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21707 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sEMG-Decomposition"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 320, 102, 1  0           []
#                                 )]
#
#  covolution_layer (Sequential)  (None, 160, 51, 121  23965       ['input_1[0][0]']
#                                 )
#
#  generate__patches (Generate_Pa  (None, None, 7744)  0           ['covolution_layer[0][0]']
#  tches)
#
#  embed__position (Embed_Positio  (None, 120, 121)    951665      ['generate__patches[0][0]']
#  n)
#
#  batch_normalization_3 (BatchNo  (None, 120, 121)    484         ['embed__position[0][0]']
#  rmalization)
#
#  layer_normalization (LayerNorm  (None, 120, 121)    242         ['batch_normalization_3[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 120, 121)    117975      ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  add (Add)                      (None, 120, 121)     0           ['multi_head_attention[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 120, 121)    242         ['add[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 120, 121)     14762       ['layer_normalization_1[0][0]']
#
#  dropout_3 (Dropout)            (None, 120, 121)     0           ['dense_2[0][0]']
#
#  add_1 (Add)                    (None, 120, 121)     0           ['dropout_3[0][0]',
#                                                                   'add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 120, 121)    242         ['add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 120, 121)    117975      ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  add_2 (Add)                    (None, 120, 121)     0           ['multi_head_attention_1[0][0]',
#                                                                   'add_1[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 120, 121)    242         ['add_2[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 120, 121)     14762       ['layer_normalization_3[0][0]']
#
#  dropout_5 (Dropout)            (None, 120, 121)     0           ['dense_4[0][0]']
#
#  add_3 (Add)                    (None, 120, 121)     0           ['dropout_5[0][0]',
#                                                                   'add_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 120, 121)    242         ['add_3[0][0]']
#  rmalization)
#
#  flatten (Flatten)              (None, 14520)        0           ['layer_normalization_4[0][0]']
#
#  dropout_6 (Dropout)            (None, 14520)        0           ['flatten[0][0]']
#
#  dense_6 (Dense)                (None, 34)           493714      ['dropout_6[0][0]']
#
#  dropout_8 (Dropout)            (None, 34)           0           ['dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 576)          20160       ['dropout_8[0][0]']
#
#  dense_8 (Dense)                (None, 34)           19618       ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 1,776,290
# Trainable params: 1,775,614
# Non-trainable params: 676
# __________________________________________________________________________________________________

# %%
run_experiment(n_folds, n_batches, n_epochs, start_subject, total_subject, session, path, 
                       input_type,n_channels, window_size,extend, extend_size, center, whiten, ratio, noise_db, std,
                      input_shape, dims, patch_size, n_patches,
                       n_transformer_layers, n_heads, transformer_units,
                       mlp_head_units, n_classes,stochastic_depth,stochastic_depth_rate, type_of_experiment)
# Out:
# ************************************************
# Experiment Two
# ************************************************
# ####################################################################################
# Loading subject 1
# ####################################################################################
# Extended.
# Size of the input data is (17152, 320, 102, 1)
# The input label shape is (17152,)
# The total number of classes is 34
# ************************************************************************************
# Loaded RAW input data
# ************************************************************************************
# Adding noise to RAW input test data
# Adding white noise to RAW input test data
# ---------------------------------------------------
# Training for fold 1 -------
# 2023-09-04 13:45:07.748989: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1492823040 exceeds 10% of free system memory.
# 2023-09-04 13:45:09.191373: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1492823040 exceeds 10% of free system memory.
# Epoch 1/150
# 2023-09-04 13:45:19.547318: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8600
# 2023-09-04 13:45:26.441846: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 358/358 [==============================] - 32s 41ms/step - loss: 3.5352 - accuracy: 0.0314
# Epoch 2/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5339 - accuracy: 0.0291
# Epoch 3/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5232 - accuracy: 0.0292
# Epoch 4/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5224 - accuracy: 0.0313
# Epoch 5/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5226 - accuracy: 0.0322
# Epoch 6/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5222 - accuracy: 0.0320
# Epoch 7/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5221 - accuracy: 0.0323
# Epoch 8/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5222 - accuracy: 0.0294
# Epoch 9/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5220 - accuracy: 0.0331
# Epoch 10/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5219 - accuracy: 0.0331
# Epoch 11/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5219 - accuracy: 0.0331
# Epoch 12/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5627 - accuracy: 0.0315
# Epoch 13/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5222 - accuracy: 0.0331
# Epoch 14/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5217 - accuracy: 0.0324
# Score for fold  1: loss of 3.52557373046875; accuracy of 2.658272162079811%
# ---------------------------------------------------
# Training for fold 2 -------
# 2023-09-04 13:49:42.573642: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1492953600 exceeds 10% of free system memory.
# 2023-09-04 13:49:43.914481: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1492953600 exceeds 10% of free system memory.
# Epoch 1/150
# 358/358 [==============================] - 18s 40ms/step - loss: 3.5196 - accuracy: 0.0382
# Epoch 2/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5238 - accuracy: 0.0288
# Epoch 3/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5231 - accuracy: 0.0298
# Epoch 4/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5232 - accuracy: 0.0298
# Epoch 5/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5230 - accuracy: 0.0299
# Epoch 6/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5229 - accuracy: 0.0256
# Score for fold  2: loss of 3.523581027984619; accuracy of 2.7461955323815346%
# ---------------------------------------------------
# Training for fold 3 -------
# 2023-09-04 13:51:20.628663: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1492953600 exceeds 10% of free system memory.
# Epoch 1/150
# 358/358 [==============================] - 17s 40ms/step - loss: 3.5354 - accuracy: 0.0272
# Epoch 2/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5251 - accuracy: 0.0299
# Epoch 3/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5235 - accuracy: 0.0280
# Epoch 4/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5235 - accuracy: 0.0302
# Epoch 5/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5233 - accuracy: 0.0308
# Epoch 6/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5232 - accuracy: 0.0297
# Epoch 7/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5231 - accuracy: 0.0314
# Epoch 8/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5232 - accuracy: 0.0297
# Epoch 9/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5231 - accuracy: 0.0324
# Epoch 10/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5229 - accuracy: 0.0319
# Epoch 11/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5229 - accuracy: 0.0310
# Epoch 12/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5228 - accuracy: 0.0323
# Epoch 13/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5228 - accuracy: 0.0315
# Epoch 14/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5228 - accuracy: 0.0323
# Score for fold  3: loss of 3.523196220397949; accuracy of 2.7112122625112534%
# Average Score per fold
# -----------------------------------------------
# > Fold 1 - Loss: 3.52557373046875 - Accuracy: 2.658272162079811%
# -----------------------------------------------
# > Fold 2 - Loss: 3.523581027984619 - Accuracy: 2.7461955323815346%
# -----------------------------------------------
# > Fold 3 - Loss: 3.523196220397949 - Accuracy: 2.7112122625112534%
# -----------------------------------------------
# Average Metrics for all folds:
# > Accuracy: 2.7052266523241997 (+- 0.03614323734150939)
# > Loss: 3.5241169929504395
# -----------------------------------------------
# ************************************************
# For subject 1 without noise
# The loss is 3.522516965866089 and accuracy is 2.705223858356476%
# For subject 1 and noise 5 dB
# The loss is 3.522516965866089 and accuracy is 2.705223858356476%
# For subject 1 and noise 10 dB
# The loss is 3.522516965866089 and accuracy is 2.705223858356476%
# For subject 1 and noise 15 dB
# The loss is 3.522516965866089 and accuracy is 2.705223858356476%
# ************************************************
# 134/134 [==============================] - 2s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 134/134 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 134/134 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 134/134 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 134/134 [==============================] - 1s 9ms/step
# ####################################################################################
# Loading subject 2
# ####################################################################################
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Extended.
# Size of the input data is (17279, 320, 102, 1)
# The input label shape is (17279,)
# The total number of classes is 34
# ************************************************************************************
# Loaded RAW input data
# ************************************************************************************
# Adding noise to RAW input test data
# Adding white noise to RAW input test data
# ---------------------------------------------------
# Training for fold 1 -------
# Epoch 1/150
# 360/360 [==============================] - 20s 45ms/step - loss: 3.5379 - accuracy: 0.0303
# Epoch 2/150
# 360/360 [==============================] - 16s 43ms/step - loss: 3.5261 - accuracy: 0.0306
# Epoch 3/150
# 360/360 [==============================] - 14s 40ms/step - loss: 3.5259 - accuracy: 0.0325
# Epoch 4/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5259 - accuracy: 0.0309
# Epoch 5/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5258 - accuracy: 0.0329
# Epoch 6/150
# 360/360 [==============================] - 14s 38ms/step - loss: 3.5258 - accuracy: 0.0329
# Epoch 7/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5256 - accuracy: 0.0329
# Epoch 8/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5256 - accuracy: 0.0329
# Epoch 9/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5256 - accuracy: 0.0329
# Epoch 10/150
# 360/360 [==============================] - 14s 38ms/step - loss: 3.5255 - accuracy: 0.0329
# Score for fold  1: loss of 3.526587963104248; accuracy of 2.708333358168602%
# ---------------------------------------------------
# Training for fold 2 -------
# Epoch 1/150
# 360/360 [==============================] - 20s 47ms/step - loss: 3.5214 - accuracy: 0.0379
# Epoch 2/150
# 360/360 [==============================] - 15s 41ms/step - loss: 3.5261 - accuracy: 0.0293
# Epoch 3/150
# 360/360 [==============================] - 14s 40ms/step - loss: 3.5257 - accuracy: 0.0319
# Epoch 4/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5257 - accuracy: 0.0324
# Epoch 5/150
# 360/360 [==============================] - 14s 40ms/step - loss: 3.5255 - accuracy: 0.0325
# Epoch 6/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5256 - accuracy: 0.0325
# Score for fold  2: loss of 3.5271286964416504; accuracy of 2.534722164273262%
# ---------------------------------------------------
# Training for fold 3 -------
# Epoch 1/150
# 360/360 [==============================] - 18s 44ms/step - loss: 3.4952 - accuracy: 0.0417
# Epoch 2/150
# 360/360 [==============================] - 13s 37ms/step - loss: 3.5076 - accuracy: 0.0370
# Epoch 3/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5223 - accuracy: 0.0308
# Epoch 4/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5263 - accuracy: 0.0302
# Epoch 5/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5260 - accuracy: 0.0299
# Epoch 6/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5259 - accuracy: 0.0315
# Score for fold  3: loss of 3.526799201965332; accuracy of 2.569890581071377%
# Average Score per fold
# -----------------------------------------------
# > Fold 1 - Loss: 3.526587963104248 - Accuracy: 2.708333358168602%
# -----------------------------------------------
# > Fold 2 - Loss: 3.5271286964416504 - Accuracy: 2.534722164273262%
# -----------------------------------------------
# > Fold 3 - Loss: 3.526799201965332 - Accuracy: 2.569890581071377%
# -----------------------------------------------
# Average Metrics for all folds:
# > Accuracy: 2.604315367837747 (+- 0.07494002543978695)
# > Loss: 3.5268386205037436
# -----------------------------------------------
# ************************************************
# For subject 2 without noise
# The loss is 3.5266876220703125 and accuracy is 2.986111119389534%
# For subject 2 and noise 5 dB
# The loss is 3.5266876220703125 and accuracy is 2.986111119389534%
# For subject 2 and noise 10 dB
# The loss is 3.5266876220703125 and accuracy is 2.986111119389534%
# For subject 2 and noise 15 dB
# The loss is 3.5266876220703125 and accuracy is 2.986111119389534%
# ************************************************
# 135/135 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 135/135 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 135/135 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 135/135 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 135/135 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ####################################################################################
# Loading subject 3
# ####################################################################################
# Extended.
# Size of the input data is (16896, 320, 102, 1)
# The input label shape is (16896,)
# The total number of classes is 33
# ************************************************************************************
# Loaded RAW input data
# ************************************************************************************
# Adding noise to RAW input test data
# Adding white noise to RAW input test data
# ---------------------------------------------------
# Training for fold 1 -------
# Epoch 1/150
# 352/352 [==============================] - 15s 38ms/step - loss: 3.5185 - accuracy: 0.0330
# Epoch 2/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.5002 - accuracy: 0.0309
# Epoch 3/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.5006 - accuracy: 0.0322
# Epoch 4/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.4992 - accuracy: 0.0307
# Epoch 5/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.4985 - accuracy: 0.0322
# Epoch 6/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.4986 - accuracy: 0.0316
# Score for fold  1: loss of 3.4996519088745117; accuracy of 2.8053976595401764%
# ---------------------------------------------------
# Training for fold 2 -------
# Epoch 1/150
# 352/352 [==============================] - 15s 38ms/step - loss: 3.5200 - accuracy: 0.0319
# Epoch 2/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.5010 - accuracy: 0.0303
# Epoch 3/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.5227 - accuracy: 0.0305
# Epoch 4/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.4991 - accuracy: 0.0312
# Epoch 5/150
# 352/352 [==============================] - 13s 36ms/step - loss: 3.4991 - accuracy: 0.0292
# Epoch 6/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.4986 - accuracy: 0.0321
# Epoch 7/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.4982 - accuracy: 0.0293
# Epoch 8/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.4983 - accuracy: 0.0328
# Epoch 9/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.4978 - accuracy: 0.0309
# Epoch 10/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.4978 - accuracy: 0.0316
# Epoch 11/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.4977 - accuracy: 0.0313
# Epoch 12/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.4974 - accuracy: 0.0313
# Epoch 13/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.4973 - accuracy: 0.0320
# Score for fold  2: loss of 3.5004758834838867; accuracy of 2.769886329770088%
# ---------------------------------------------------
# Training for fold 3 -------
# Epoch 1/150
# 352/352 [==============================] - 17s 43ms/step - loss: 3.5209 - accuracy: 0.0307
# Epoch 2/150
# 352/352 [==============================] - 13s 37ms/step - loss: 3.5008 - accuracy: 0.0319
# Epoch 3/150
# 352/352 [==============================] - 13s 37ms/step - loss: 3.4997 - accuracy: 0.0301
# Epoch 4/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.5010 - accuracy: 0.0280
# Epoch 5/150
# 352/352 [==============================] - 13s 36ms/step - loss: 3.4995 - accuracy: 0.0290
# Epoch 6/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.4992 - accuracy: 0.0299
# Epoch 7/150
# 352/352 [==============================] - 12s 35ms/step - loss: 3.4990 - accuracy: 0.0315
# Score for fold  3: loss of 3.4999773502349854; accuracy of 3.0184658244252205%
# Average Score per fold
# -----------------------------------------------
# > Fold 1 - Loss: 3.4996519088745117 - Accuracy: 2.8053976595401764%
# -----------------------------------------------
# > Fold 2 - Loss: 3.5004758834838867 - Accuracy: 2.769886329770088%
# -----------------------------------------------
# > Fold 3 - Loss: 3.4999773502349854 - Accuracy: 3.0184658244252205%
# -----------------------------------------------
# Average Metrics for all folds:
# > Accuracy: 2.8645832712451615 (+- 0.1097729285553295)
# > Loss: 3.500035047531128
# -----------------------------------------------
# ************************************************
# For subject 3 without noise
# The loss is 3.50112247467041 and accuracy is 2.5331439450383186%
# For subject 3 and noise 5 dB
# The loss is 3.50112247467041 and accuracy is 2.5331439450383186%
# For subject 3 and noise 10 dB
# The loss is 3.50112247467041 and accuracy is 2.5331439450383186%
# For subject 3 and noise 15 dB
# The loss is 3.50112247467041 and accuracy is 2.5331439450383186%
# ************************************************
# 132/132 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 132/132 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 132/132 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 132/132 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 132/132 [==============================] - 1s 8ms/step
# ####################################################################################
# Loading subject 4
# ####################################################################################
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Extended.
# Size of the input data is (17279, 320, 102, 1)
# The input label shape is (17279,)
# The total number of classes is 34
# ************************************************************************************
# Loaded RAW input data
# ************************************************************************************
# Adding noise to RAW input test data
# Adding white noise to RAW input test data
# ---------------------------------------------------
# Training for fold 1 -------
# Epoch 1/150
# 360/360 [==============================] - 25s 42ms/step - loss: 3.5342 - accuracy: 0.0306
# Epoch 2/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5270 - accuracy: 0.0291
# Epoch 3/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5270 - accuracy: 0.0301
# Epoch 4/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5257 - accuracy: 0.0303
# Epoch 5/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5255 - accuracy: 0.0313
# Epoch 6/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5255 - accuracy: 0.0313
# Epoch 7/150
# 360/360 [==============================] - 14s 38ms/step - loss: 3.5253 - accuracy: 0.0306
# Epoch 8/150
# 360/360 [==============================] - 14s 38ms/step - loss: 3.5254 - accuracy: 0.0292
# Epoch 9/150
# 360/360 [==============================] - 14s 38ms/step - loss: 3.5253 - accuracy: 0.0299
# Epoch 10/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5252 - accuracy: 0.0304
# Score for fold  1: loss of 3.5283162593841553; accuracy of 2.829861082136631%
# ---------------------------------------------------
# Training for fold 2 -------
# Epoch 1/150
# 360/360 [==============================] - 18s 42ms/step - loss: 3.5388 - accuracy: 0.0326
# Epoch 2/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5260 - accuracy: 0.0299
# Epoch 3/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5258 - accuracy: 0.0315
# Epoch 4/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5259 - accuracy: 0.0324
# Epoch 5/150
# 360/360 [==============================] - 14s 40ms/step - loss: 3.5256 - accuracy: 0.0313
# Epoch 6/150
# 360/360 [==============================] - 14s 39ms/step - loss: 3.5257 - accuracy: 0.0324
# Score for fold  2: loss of 3.527553081512451; accuracy of 2.760416641831398%
# ---------------------------------------------------
# Training for fold 3 -------
# Epoch 1/150
# 360/360 [==============================] - 15s 37ms/step - loss: 3.5308 - accuracy: 0.0320
# Epoch 2/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5263 - accuracy: 0.0312
# Epoch 3/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5269 - accuracy: 0.0297
# Epoch 4/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5260 - accuracy: 0.0295
# Epoch 5/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5259 - accuracy: 0.0292
# Epoch 6/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5259 - accuracy: 0.0297
# Score for fold  3: loss of 3.526822805404663; accuracy of 2.4483418092131615%
# Average Score per fold
# -----------------------------------------------
# > Fold 1 - Loss: 3.5283162593841553 - Accuracy: 2.829861082136631%
# -----------------------------------------------
# > Fold 2 - Loss: 3.527553081512451 - Accuracy: 2.760416641831398%
# -----------------------------------------------
# > Fold 3 - Loss: 3.526822805404663 - Accuracy: 2.4483418092131615%
# -----------------------------------------------
# Average Metrics for all folds:
# > Accuracy: 2.67953984439373 (+- 0.16592173089711784)
# > Loss: 3.52756404876709
# -----------------------------------------------
# ************************************************
# For subject 4 without noise
# The loss is 3.526352643966675 and accuracy is 3.1712964177131653%
# For subject 4 and noise 5 dB
# The loss is 3.526352643966675 and accuracy is 3.1712964177131653%
# For subject 4 and noise 10 dB
# The loss is 3.526352882385254 and accuracy is 3.1712964177131653%
# For subject 4 and noise 15 dB
# The loss is 3.526353120803833 and accuracy is 3.1712964177131653%
# ************************************************
# 135/135 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 135/135 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 135/135 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 135/135 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 135/135 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ####################################################################################
# Loading subject 5
# ####################################################################################
# Extended.
# Size of the input data is (17152, 320, 102, 1)
# The input label shape is (17152,)
# The total number of classes is 34
# ************************************************************************************
# Loaded RAW input data
# ************************************************************************************
# Adding noise to RAW input test data
# Adding white noise to RAW input test data
# ---------------------------------------------------
# Training for fold 1 -------
# Epoch 1/150
# 358/358 [==============================] - 18s 40ms/step - loss: 3.5333 - accuracy: 0.0292
# Epoch 2/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5234 - accuracy: 0.0298
# Epoch 3/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5227 - accuracy: 0.0280
# Epoch 4/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5227 - accuracy: 0.0261
# Epoch 5/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5226 - accuracy: 0.0298
# Epoch 6/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5224 - accuracy: 0.0306
# Epoch 7/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5223 - accuracy: 0.0297
# Epoch 8/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5423 - accuracy: 0.0321
# Epoch 9/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5224 - accuracy: 0.0311
# Epoch 10/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5221 - accuracy: 0.0257
# Epoch 11/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5221 - accuracy: 0.0295
# Epoch 12/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5221 - accuracy: 0.0282
# Epoch 13/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5220 - accuracy: 0.0309
# Score for fold  1: loss of 3.5229036808013916; accuracy of 2.8331585228443146%
# ---------------------------------------------------
# Training for fold 2 -------
# Epoch 1/150
# 358/358 [==============================] - 17s 39ms/step - loss: 3.5345 - accuracy: 0.0277
# Epoch 2/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5228 - accuracy: 0.0317
# Epoch 3/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5226 - accuracy: 0.0313
# Epoch 4/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5225 - accuracy: 0.0303
# Epoch 5/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5223 - accuracy: 0.0324
# Epoch 6/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5225 - accuracy: 0.0296
# Epoch 7/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5223 - accuracy: 0.0306
# Epoch 8/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5221 - accuracy: 0.0289
# Epoch 9/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5222 - accuracy: 0.0319
# Epoch 10/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5220 - accuracy: 0.0275
# Score for fold  2: loss of 3.5231192111968994; accuracy of 2.7287038043141365%
# ---------------------------------------------------
# Training for fold 3 -------
# Epoch 1/150
# 358/358 [==============================] - 21s 49ms/step - loss: 3.5309 - accuracy: 0.0290
# Epoch 2/150
# 358/358 [==============================] - 15s 41ms/step - loss: 3.5270 - accuracy: 0.0316
# Epoch 3/150
# 358/358 [==============================] - 16s 44ms/step - loss: 3.5216 - accuracy: 0.0291
# Epoch 4/150
# 358/358 [==============================] - 17s 46ms/step - loss: 3.5215 - accuracy: 0.0300
# Epoch 5/150
# 358/358 [==============================] - 15s 42ms/step - loss: 3.5213 - accuracy: 0.0324
# Epoch 6/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5212 - accuracy: 0.0311
# Epoch 7/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5211 - accuracy: 0.0322
# Epoch 8/150
# 358/358 [==============================] - 14s 40ms/step - loss: 3.5210 - accuracy: 0.0309
# Epoch 9/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5210 - accuracy: 0.0311
# Epoch 10/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5341 - accuracy: 0.0331
# Epoch 11/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5214 - accuracy: 0.0329
# Epoch 12/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5207 - accuracy: 0.0317
# Epoch 13/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5207 - accuracy: 0.0307
# Epoch 14/150
# 358/358 [==============================] - 14s 38ms/step - loss: 3.5207 - accuracy: 0.0321
# Epoch 15/150
# 358/358 [==============================] - 14s 39ms/step - loss: 3.5206 - accuracy: 0.0318
# Score for fold  3: loss of 3.528632402420044; accuracy of 2.588770352303982%
# Average Score per fold
# -----------------------------------------------
# > Fold 1 - Loss: 3.5229036808013916 - Accuracy: 2.8331585228443146%
# -----------------------------------------------
# > Fold 2 - Loss: 3.5231192111968994 - Accuracy: 2.7287038043141365%
# -----------------------------------------------
# > Fold 3 - Loss: 3.528632402420044 - Accuracy: 2.588770352303982%
# -----------------------------------------------
# Average Metrics for all folds:
# > Accuracy: 2.716877559820811 (+- 0.10012089198938329)
# > Loss: 3.524885098139445
# -----------------------------------------------
# ************************************************
# For subject 5 without noise
# The loss is 3.527528762817383 and accuracy is 2.845149300992489%
# For subject 5 and noise 5 dB
# The loss is 3.527528762817383 and accuracy is 2.845149300992489%
# For subject 5 and noise 10 dB
# The loss is 3.527528762817383 and accuracy is 2.845149300992489%
# For subject 5 and noise 15 dB
# The loss is 3.527528762817383 and accuracy is 2.845149300992489%
# ************************************************
# 134/134 [==============================] - 2s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 134/134 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 134/134 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 134/134 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 134/134 [==============================] - 1s 8ms/step
# ####################################################################################
# Loading subject 6
# ####################################################################################
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Extended.
# Size of the input data is (17021, 320, 102, 1)
# The input label shape is (17021,)
# The total number of classes is 34
# ************************************************************************************
# Loaded RAW input data
# ************************************************************************************
# Adding noise to RAW input test data
# Adding white noise to RAW input test data
# ---------------------------------------------------
# Training for fold 1 -------
# Epoch 1/150
# 355/355 [==============================] - 18s 42ms/step - loss: 3.5360 - accuracy: 0.0307
# Epoch 2/150
# 355/355 [==============================] - 14s 40ms/step - loss: 3.5241 - accuracy: 0.0329
# Epoch 3/150
# 355/355 [==============================] - 14s 40ms/step - loss: 3.5238 - accuracy: 0.0316
# Epoch 4/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5238 - accuracy: 0.0304
# Epoch 5/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5237 - accuracy: 0.0329
# Epoch 6/150
# 355/355 [==============================] - 14s 38ms/step - loss: 3.5236 - accuracy: 0.0319
# Epoch 7/150
# 355/355 [==============================] - 14s 38ms/step - loss: 3.5236 - accuracy: 0.0323
# Score for fold  1: loss of 3.526381254196167; accuracy of 2.6965104043483734%
# ---------------------------------------------------
# Training for fold 2 -------
# Epoch 1/150
# 355/355 [==============================] - 17s 40ms/step - loss: 3.5375 - accuracy: 0.0328
# Epoch 2/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5250 - accuracy: 0.0291
# Epoch 3/150
# 355/355 [==============================] - 14s 38ms/step - loss: 3.5248 - accuracy: 0.0282
# Epoch 4/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5247 - accuracy: 0.0307
# Epoch 5/150
# 355/355 [==============================] - 14s 38ms/step - loss: 3.5247 - accuracy: 0.0302
# Epoch 6/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5247 - accuracy: 0.0303
# Score for fold  2: loss of 3.525103807449341; accuracy of 2.485019341111183%
# ---------------------------------------------------
# Training for fold 3 -------
# Epoch 1/150
# 355/355 [==============================] - 17s 41ms/step - loss: 3.5273 - accuracy: 0.0349
# Epoch 2/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5244 - accuracy: 0.0321
# Epoch 3/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5242 - accuracy: 0.0305
# Epoch 4/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5359 - accuracy: 0.0315
# Epoch 5/150
# 355/355 [==============================] - 14s 38ms/step - loss: 3.5307 - accuracy: 0.0306
# Epoch 6/150
# 355/355 [==============================] - 13s 38ms/step - loss: 3.5240 - accuracy: 0.0297
# Score for fold  3: loss of 3.526618719100952; accuracy of 2.4854574352502823%
# Average Score per fold
# -----------------------------------------------
# > Fold 1 - Loss: 3.526381254196167 - Accuracy: 2.6965104043483734%
# -----------------------------------------------
# > Fold 2 - Loss: 3.525103807449341 - Accuracy: 2.485019341111183%
# -----------------------------------------------
# > Fold 3 - Loss: 3.526618719100952 - Accuracy: 2.4854574352502823%
# -----------------------------------------------
# Average Metrics for all folds:
# > Accuracy: 2.5556623935699463 (+- 0.09959474412771864)
# > Loss: 3.5260345935821533
# -----------------------------------------------
# ************************************************
# For subject 6 without noise
# The loss is 3.524341106414795 and accuracy is 3.031015023589134%
# For subject 6 and noise 5 dB
# The loss is 3.524341106414795 and accuracy is 3.031015023589134%
# For subject 6 and noise 10 dB
# The loss is 3.524341106414795 and accuracy is 3.031015023589134%
# For subject 6 and noise 15 dB
# The loss is 3.524341106414795 and accuracy is 3.031015023589134%
# ************************************************
# 133/133 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 133/133 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 133/133 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 133/133 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 133/133 [==============================] - 1s 8ms/step
# ####################################################################################
# Loading subject 7
# ####################################################################################
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Extended.
# Size of the input data is (17408, 320, 102, 1)
# The input label shape is (17408,)
# The total number of classes is 34
# ************************************************************************************
# Loaded RAW input data
# ************************************************************************************
# Adding noise to RAW input test data
# Adding white noise to RAW input test data
# ---------------------------------------------------
# Training for fold 1 -------
# Epoch 1/150
# 363/363 [==============================] - 17s 40ms/step - loss: 3.5393 - accuracy: 0.0291
# Epoch 2/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5266 - accuracy: 0.0294
# Epoch 3/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5264 - accuracy: 0.0310
# Epoch 4/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5264 - accuracy: 0.0301
# Epoch 5/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5263 - accuracy: 0.0314
# Epoch 6/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5263 - accuracy: 0.0311
# Epoch 7/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5263 - accuracy: 0.0292
# Epoch 8/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5262 - accuracy: 0.0314
# Epoch 9/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5262 - accuracy: 0.0314
# Epoch 10/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5262 - accuracy: 0.0314
# Score for fold  1: loss of 3.528501272201538; accuracy of 2.584869973361492%
# ---------------------------------------------------
# Training for fold 2 -------
# Epoch 1/150
# 363/363 [==============================] - 21s 51ms/step - loss: 3.5382 - accuracy: 0.0274
# Epoch 2/150
# 363/363 [==============================] - 14s 40ms/step - loss: 3.5267 - accuracy: 0.0312
# Epoch 3/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5266 - accuracy: 0.0293
# Epoch 4/150
# 363/363 [==============================] - 14s 40ms/step - loss: 3.5265 - accuracy: 0.0309
# Epoch 5/150
# 363/363 [==============================] - 15s 40ms/step - loss: 3.5264 - accuracy: 0.0304
# Epoch 6/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5263 - accuracy: 0.0286
# Epoch 7/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5263 - accuracy: 0.0299
# Score for fold  2: loss of 3.5280535221099854; accuracy of 2.7744270861148834%
# ---------------------------------------------------
# Training for fold 3 -------
# Epoch 1/150
# 363/363 [==============================] - 18s 39ms/step - loss: 3.5389 - accuracy: 0.0296
# Epoch 2/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5277 - accuracy: 0.0287
# Epoch 3/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5266 - accuracy: 0.0303
# Epoch 4/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5267 - accuracy: 0.0317
# Epoch 5/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5266 - accuracy: 0.0317
# Epoch 6/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5265 - accuracy: 0.0308
# Epoch 7/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5665 - accuracy: 0.0304
# Epoch 8/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5268 - accuracy: 0.0317
# Epoch 9/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5265 - accuracy: 0.0317
# Score for fold  3: loss of 3.5274572372436523; accuracy of 2.774905227124691%
# Average Score per fold
# -----------------------------------------------
# > Fold 1 - Loss: 3.528501272201538 - Accuracy: 2.584869973361492%
# -----------------------------------------------
# > Fold 2 - Loss: 3.5280535221099854 - Accuracy: 2.7744270861148834%
# -----------------------------------------------
# > Fold 3 - Loss: 3.5274572372436523 - Accuracy: 2.774905227124691%
# -----------------------------------------------
# Average Metrics for all folds:
# > Accuracy: 2.7114007622003555 (+- 0.08947099175280253)
# > Loss: 3.528004010518392
# -----------------------------------------------
# ************************************************
# For subject 7 without noise
# The loss is 3.527289867401123 and accuracy is 2.5505514815449715%
# For subject 7 and noise 5 dB
# The loss is 3.527289867401123 and accuracy is 2.5505514815449715%
# For subject 7 and noise 10 dB
# The loss is 3.527289867401123 and accuracy is 2.5505514815449715%
# For subject 7 and noise 15 dB
# The loss is 3.527289867401123 and accuracy is 2.5505514815449715%
# ************************************************
# 136/136 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 136/136 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 136/136 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 136/136 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 136/136 [==============================] - 1s 8ms/step
# ####################################################################################
# Loading subject 8
# ...
# 360/360 [==============================] - 14s 38ms/step - loss: 3.5257 - accuracy: 0.0297
# Epoch 4/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5260 - accuracy: 0.0296
# Epoch 5/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5281 - accuracy: 0.0289
# Epoch 6/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5335 - accuracy: 0.0299
# Epoch 7/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5256 - accuracy: 0.0300
# Epoch 8/150
# 360/360 [==============================] - 13s 37ms/step - loss: 3.5255 - accuracy: 0.0306
# Epoch 9/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5255 - accuracy: 0.0284
# Epoch 10/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5254 - accuracy: 0.0303
# Epoch 11/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5254 - accuracy: 0.0301
# Epoch 12/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5253 - accuracy: 0.0299
# Epoch 13/150
# 360/360 [==============================] - 13s 35ms/step - loss: 3.5253 - accuracy: 0.0315
# Epoch 14/150
# 360/360 [==============================] - 13s 35ms/step - loss: 3.5253 - accuracy: 0.0306
# Epoch 15/150
# 360/360 [==============================] - 13s 35ms/step - loss: 3.5252 - accuracy: 0.0315
# Epoch 16/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5252 - accuracy: 0.0315
# Epoch 17/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5252 - accuracy: 0.0299
# Epoch 18/150
# 360/360 [==============================] - 13s 36ms/step - loss: 3.5252 - accuracy: 0.0305
# Score for fold  3: loss of 3.5268571376800537; accuracy of 2.8129883110523224%
# Average Score per fold
# -----------------------------------------------
# > Fold 1 - Loss: 3.5261030197143555 - Accuracy: 2.777777798473835%
# -----------------------------------------------
# > Fold 2 - Loss: 3.5290091037750244 - Accuracy: 2.795138955116272%
# -----------------------------------------------
# > Fold 3 - Loss: 3.5268571376800537 - Accuracy: 2.8129883110523224%
# -----------------------------------------------
# Average Metrics for all folds:
# > Accuracy: 2.7953016882141433 (+- 0.014375092128535195)
# > Loss: 3.527323087056478
# -----------------------------------------------
# ************************************************
# For subject 18 without noise
# The loss is 3.5274417400360107 and accuracy is 2.6620371267199516%
# For subject 18 and noise 5 dB
# The loss is 3.5274417400360107 and accuracy is 2.6620371267199516%
# For subject 18 and noise 10 dB
# The loss is 3.5274417400360107 and accuracy is 2.6620371267199516%
# For subject 18 and noise 15 dB
# The loss is 3.5274417400360107 and accuracy is 2.6620371267199516%
# ************************************************
# 135/135 [==============================] - 1s 9ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 135/135 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 135/135 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 135/135 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 135/135 [==============================] - 1s 8ms/step
# ####################################################################################
# Loading subject 19
# ####################################################################################
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Extended.
# Size of the input data is (17023, 320, 102, 1)
# The input label shape is (17023,)
# The total number of classes is 34
# ************************************************************************************
# Loaded RAW input data
# ************************************************************************************
# Adding noise to RAW input test data
# Adding white noise to RAW input test data
# ---------------------------------------------------
# Training for fold 1 -------
# Epoch 1/150
# 355/355 [==============================] - 17s 41ms/step - loss: 3.5377 - accuracy: 0.0294
# Epoch 2/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5223 - accuracy: 0.0303
# Epoch 3/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5223 - accuracy: 0.0293
# Epoch 4/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5446 - accuracy: 0.0286
# Epoch 5/150
# 355/355 [==============================] - 14s 40ms/step - loss: 3.5222 - accuracy: 0.0299
# Epoch 6/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5218 - accuracy: 0.0316
# Epoch 7/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5218 - accuracy: 0.0277
# Epoch 8/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5218 - accuracy: 0.0286
# Epoch 9/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5218 - accuracy: 0.0287
# Epoch 10/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5217 - accuracy: 0.0280
# Epoch 11/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5216 - accuracy: 0.0280
# Score for fold  1: loss of 3.5221550464630127; accuracy of 2.6960352435708046%
# ---------------------------------------------------
# Training for fold 2 -------
# Epoch 1/150
# 355/355 [==============================] - 18s 41ms/step - loss: 3.5373 - accuracy: 0.0278
# Epoch 2/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5249 - accuracy: 0.0293
# Epoch 3/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5222 - accuracy: 0.0310
# Epoch 4/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5223 - accuracy: 0.0290
# Epoch 5/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5221 - accuracy: 0.0311
# Epoch 6/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5219 - accuracy: 0.0309
# Epoch 7/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5218 - accuracy: 0.0281
# Epoch 8/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5218 - accuracy: 0.0313
# Epoch 9/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5218 - accuracy: 0.0307
# Epoch 10/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5217 - accuracy: 0.0304
# Epoch 11/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5216 - accuracy: 0.0308
# Epoch 12/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5216 - accuracy: 0.0291
# Epoch 13/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5216 - accuracy: 0.0293
# Score for fold  2: loss of 3.521976947784424; accuracy of 2.7493830770254135%
# ---------------------------------------------------
# Training for fold 3 -------
# Epoch 1/150
# 355/355 [==============================] - 17s 40ms/step - loss: 3.5347 - accuracy: 0.0293
# Epoch 2/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5216 - accuracy: 0.0325
# Epoch 3/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5212 - accuracy: 0.0308
# Epoch 4/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5212 - accuracy: 0.0333
# Epoch 5/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5211 - accuracy: 0.0322
# Epoch 6/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5210 - accuracy: 0.0333
# Epoch 7/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5210 - accuracy: 0.0321
# Epoch 8/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5209 - accuracy: 0.0320
# Epoch 9/150
# 355/355 [==============================] - 14s 39ms/step - loss: 3.5208 - accuracy: 0.0333
# Score for fold  3: loss of 3.5238401889801025; accuracy of 2.6436377316713333%
# Average Score per fold
# -----------------------------------------------
# > Fold 1 - Loss: 3.5221550464630127 - Accuracy: 2.6960352435708046%
# -----------------------------------------------
# > Fold 2 - Loss: 3.521976947784424 - Accuracy: 2.7493830770254135%
# -----------------------------------------------
# > Fold 3 - Loss: 3.5238401889801025 - Accuracy: 2.6436377316713333%
# -----------------------------------------------
# Average Metrics for all folds:
# > Accuracy: 2.6963520174225173 (+- 0.04317093756427866)
# > Loss: 3.5226573944091797
# -----------------------------------------------
# ************************************************
# For subject 19 without noise
# The loss is 3.5232160091400146 and accuracy is 2.631578966975212%
# For subject 19 and noise 5 dB
# The loss is 3.5232160091400146 and accuracy is 2.631578966975212%
# For subject 19 and noise 10 dB
# The loss is 3.5232160091400146 and accuracy is 2.631578966975212%
# For subject 19 and noise 15 dB
# The loss is 3.5232160091400146 and accuracy is 2.631578966975212%
# ************************************************
# 133/133 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 133/133 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 133/133 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 133/133 [==============================] - 1s 8ms/step
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 133/133 [==============================] - 1s 8ms/step
# ####################################################################################
# Loading subject 20
# ####################################################################################
# /home/bmis/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Extended.
# Size of the input data is (17408, 320, 102, 1)
# The input label shape is (17408,)
# The total number of classes is 34
# ************************************************************************************
# Loaded RAW input data
# ************************************************************************************
# Adding noise to RAW input test data
# Adding white noise to RAW input test data
# ---------------------------------------------------
# Training for fold 1 -------
# Epoch 1/150
# 363/363 [==============================] - 18s 40ms/step - loss: 3.5380 - accuracy: 0.0326
# Epoch 2/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5264 - accuracy: 0.0308
# Epoch 3/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5273 - accuracy: 0.0304
# Epoch 4/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5348 - accuracy: 0.0290
# Epoch 5/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5263 - accuracy: 0.0296
# Epoch 6/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5262 - accuracy: 0.0321
# Score for fold  1: loss of 3.5290465354919434; accuracy of 2.584869973361492%
# ---------------------------------------------------
# Training for fold 2 -------
# Epoch 1/150
# 363/363 [==============================] - 18s 39ms/step - loss: 3.5385 - accuracy: 0.0285
# Epoch 2/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5265 - accuracy: 0.0323
# Epoch 3/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5263 - accuracy: 0.0323
# Epoch 4/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5262 - accuracy: 0.0310
# Epoch 5/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5751 - accuracy: 0.0315
# Epoch 6/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5263 - accuracy: 0.0314
# Epoch 7/150
# 363/363 [==============================] - 14s 38ms/step - loss: 3.5261 - accuracy: 0.0323
# Score for fold  2: loss of 3.5285120010375977; accuracy of 2.7399620041251183%
# ---------------------------------------------------
# Training for fold 3 -------
# Epoch 1/150
# 363/363 [==============================] - 17s 40ms/step - loss: 3.5353 - accuracy: 0.0296
# Epoch 2/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5328 - accuracy: 0.0303
# Epoch 3/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5264 - accuracy: 0.0299
# Epoch 4/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5262 - accuracy: 0.0276
# Epoch 5/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5261 - accuracy: 0.0298
# Epoch 6/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5260 - accuracy: 0.0270
# Epoch 7/150
# 363/363 [==============================] - 14s 39ms/step - loss: 3.5261 - accuracy: 0.0282
# Score for fold  3: loss of 3.52959942817688; accuracy of 2.619786188006401%
# Average Score per fold
# -----------------------------------------------
# > Fold 1 - Loss: 3.5290465354919434 - Accuracy: 2.584869973361492%
# -----------------------------------------------
# > Fold 2 - Loss: 3.5285120010375977 - Accuracy: 2.7399620041251183%
# -----------------------------------------------
# > Fold 3 - Loss: 3.52959942817688 - Accuracy: 2.619786188006401%
# -----------------------------------------------
# Average Metrics for all folds:
# > Accuracy: 2.648206055164337 (+- 0.06642866418724393)
# > Loss: 3.52905265490214
# -----------------------------------------------
# ************************************************
# For subject 20 without noise
# The loss is 3.528468132019043 and accuracy is 2.8952205553650856%
# For subject 20 and noise 5 dB
# The loss is 3.528468132019043 and accuracy is 2.8952205553650856%
# For subject 20 and noise 10 dB
